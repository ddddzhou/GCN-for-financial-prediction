# %%
import os
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from datetime import date, timedelta

from scipy.stats import skew, kurtosis

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K

# %%
from spektral_utilities import *
from spektral_gcn import GraphConv

# %%
### READ DATA ###

df = pd.read_csv('终极数据.csv')
df['date'] = pd.to_datetime(df['date'])

print(df.shape)
df.head()
# Out:
# (43840, 4)
#         date  store  item     sales
# 0 2018-05-01      1     1  0.096932
# 1 2018-05-02      1     1  0.099723
# 2 2018-05-03      1     1  0.108121
# 3 2018-05-04      1     1  0.107439
# 4 2018-05-05      1     1  0.109842

# %%
### SWITCH DATA FROM VERTICAL TO HORIZONTAL FORMAT ###

unstaked_df = df.copy()
unstaked_df['id'] = df['item'].astype(str)+'_'+df['store'].astype(str)
unstaked_df.set_index(['id','date'], inplace=True)
unstaked_df.drop(['store','item'], axis=1, inplace=True)
unstaked_df = unstaked_df.astype(float).unstack()
unstaked_df.columns = unstaked_df.columns.get_level_values(1)

print(unstaked_df.shape)
unstaked_df.head()
# Out:
# (40, 1096)
# date  2018-05-01  2018-05-02  2018-05-03  2018-05-04  2018-05-05  2018-05-06  \
# id
# 1_1     0.096932    0.099723    0.108121    0.107439    0.109842    0.106574
# 1_10    0.009425    0.009661    0.009425    0.009661    0.009425    0.008718
# 1_2     0.218467    0.224748    0.258515    0.260840    0.273160    0.263811
# 1_3     0.411049    0.425342    0.438011    0.443275    0.450044    0.428029
# 1_4     0.530933    0.557377    0.547866    0.537395    0.536107    0.520699
#
# date  2018-05-07  2018-05-08  2018-05-09  2018-05-10  ...  2021-04-21  \
# id                                                    ...
# 1_1     0.102847    0.098947    0.100981    0.096117  ...    0.838827
# 1_10    0.008718    0.008954    0.009189    0.008954  ...    0.850848
# 1_2     0.249248    0.247184    0.248352    0.238229  ...    0.846793
# 1_3     0.408785    0.394569    0.384911    0.360979  ...    0.678987
# 1_4     0.519534    0.488758    0.498676    0.473668  ...    0.879654
#
# date  2021-04-22  2021-04-23  2021-04-24  2021-04-25  2021-04-26  2021-04-27  \
# id
# 1_1     0.804162    0.794448    0.776961    0.758303    0.842148    0.858994
# 1_10    0.826343    0.823987    0.731385    0.740811    0.823516    0.863101
# 1_2     0.861776    0.849210    0.792913    0.830307    0.910873    0.960007
# 1_3     0.601585    0.608272    0.537645    0.528052    0.723999    0.744437
# 1_4     0.807707    0.825972    0.894780    0.828745    0.954999    0.948704
#
# date  2021-04-28  2021-04-29  2021-04-30
# id
# 1_1     0.855759    0.834526    0.903492
# 1_10    0.850377    0.855325    0.894910
# 1_2     0.990242    0.994265    1.000000
# 1_3     0.718717    0.742320    0.859323
# 1_4     0.976886    0.961894    1.000000
#
# [5 rows x 1096 columns]

# %%
### UTILITY FUNCTIONS FOR FEATURE ENGINEERING ###

sequence_length = 14



def get_timespan(df, today, days):    
    df = df[pd.date_range(today - timedelta(days=days), 
            periods=days, freq='D')] # day - n_days <= dates < day    
    return df

def create_features(df, today, seq_len):
    
    all_sequence = get_timespan(df, today, seq_len).values
    
    group_store = all_sequence.reshape((-1, 10, seq_len))
    
    store_corr = np.stack([np.corrcoef(i) for i in group_store], axis=0)
    
    store_features = np.stack([
              group_store.mean(axis=2),
              group_store[:,:,int(sequence_length/2):].mean(axis=2),
              group_store.std(axis=2),
              group_store[:,:,int(sequence_length/2):].std(axis=2),
              skew(group_store, axis=2),
              kurtosis(group_store, axis=2),
              np.apply_along_axis(lambda x: np.polyfit(np.arange(0, sequence_length), x, 1)[0], 2, group_store)
            ], axis=1)
    
    group_store = np.transpose(group_store, (0,2,1))
    store_features = np.transpose(store_features, (0,2,1))
    
    return group_store, store_corr, store_features

def create_label(df, today):
    
    y = df[today].values
    
    return y.reshape((-1, 10))

# %%
### PLOT A SEQUENCE OF SALES FOR ITEM 10 IN ALL STORES ###

sequence = get_timespan(unstaked_df, date(2021,4,1), 30)
sequence.head(10).T.plot(figsize=(14,5))
plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
### DEFINE TRAIN, VALID, TEST DATES ###

train_date = date(2018, 5, 1)
valid_date = date(2020, 5, 1)
test_date = date(2020, 10, 30)

# %%
### CREATE TRAIN FEATURES ###

X_seq, X_cor, X_feat, y = [], [], [], []

for d in tqdm(pd.date_range(train_date+timedelta(days=sequence_length), valid_date)):
    seq_, corr_, feat_ = create_features(unstaked_df, d, sequence_length)
    y_ = create_label(unstaked_df, d)
    X_seq.append(seq_), X_cor.append(corr_), X_feat.append(feat_), y.append(y_)
    
X_train_seq = np.concatenate(X_seq, axis=0).astype('float16')
X_train_cor = np.concatenate(X_cor, axis=0).astype('float16')
X_train_feat = np.concatenate(X_feat, axis=0).astype('float16')
y_train = np.concatenate(y, axis=0).astype('float16')

print(X_train_seq.shape, X_train_cor.shape, X_train_feat.shape, y_train.shape)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 718/718 [00:02<00:00, 245.21it/s]
# (2872, 14, 10) (2872, 10, 10) (2872, 10, 7) (2872, 10)

# %%
### CREATE VALID FEATURES ###

X_seq, X_cor, X_feat, y = [], [], [], []

for d in tqdm(pd.date_range(valid_date+timedelta(days=sequence_length), test_date)):
    seq_, corr_, feat_ = create_features(unstaked_df, d, sequence_length)
    y_ = create_label(unstaked_df, d)
    X_seq.append(seq_), X_cor.append(corr_), X_feat.append(feat_), y.append(y_)
    
X_valid_seq = np.concatenate(X_seq, axis=0).astype('float16')
X_valid_cor = np.concatenate(X_cor, axis=0).astype('float16')
X_valid_feat = np.concatenate(X_feat, axis=0).astype('float16')
y_valid = np.concatenate(y, axis=0).astype('float16')

print(X_valid_seq.shape, X_valid_cor.shape, X_valid_feat.shape, y_valid.shape)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 169/169 [00:00<00:00, 245.82it/s]
# (676, 14, 10) (676, 10, 10) (676, 10, 7) (676, 10)

# %%
### CREATE TEST FEATURES ###

X_seq, X_cor, X_feat, y = [], [], [], []

for d in tqdm(pd.date_range(test_date+timedelta(days=sequence_length), date(2021, 4, 30))):
    seq_, corr_, feat_ = create_features(unstaked_df, d, sequence_length)
    y_ = create_label(unstaked_df, d)
    X_seq.append(seq_), X_cor.append(corr_), X_feat.append(feat_), y.append(y_)
    
X_test_seq = np.concatenate(X_seq, axis=0).astype('float16')
X_test_cor = np.concatenate(X_cor, axis=0).astype('float16')
X_test_feat = np.concatenate(X_feat, axis=0).astype('float16')
y_test = np.concatenate(y, axis=0).astype('float16')

print(X_test_seq.shape, X_test_cor.shape, X_test_feat.shape, y_test.shape)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 169/169 [00:00<00:00, 242.20it/s]
# (676, 14, 10) (676, 10, 10) (676, 10, 7) (676, 10)

# %%
### SCALE SEQUENCES ###

scaler_seq = StandardScaler()
scaler_feat = StandardScaler()

X_train_seq = scaler_seq.fit_transform(X_train_seq.reshape(-1,10)).reshape(X_train_seq.shape)
X_valid_seq = scaler_seq.transform(X_valid_seq.reshape(-1,10)).reshape(X_valid_seq.shape)
X_test_seq = scaler_seq.transform(X_test_seq.reshape(-1,10)).reshape(X_test_seq.shape)

y_train = scaler_seq.transform(y_train)
y_valid = scaler_seq.transform(y_valid)
y_test = scaler_seq.transform(y_test)

X_train_feat = scaler_feat.fit_transform(X_train_feat.reshape(-1,10)).reshape(X_train_feat.shape)
X_valid_feat = scaler_feat.transform(X_valid_feat.reshape(-1,10)).reshape(X_valid_feat.shape)
X_test_feat = scaler_feat.transform(X_test_feat.reshape(-1,10)).reshape(X_test_feat.shape)

# %%
### OBTAIN LAPLACIANS FROM CORRELATIONS ###

X_train_lap = localpooling_filter(1 - np.abs(X_train_cor))
X_valid_lap = localpooling_filter(1 - np.abs(X_valid_cor))
X_test_lap = localpooling_filter(1 - np.abs(X_test_cor))

# %%
def set_seed(seed):
    
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)


def get_model():
    
    set_seed(33)

    opt = Adam(learning_rate=0.001)

    inp_seq = Input((sequence_length, 10))
    inp_lap = Input((10, 10))
    inp_feat = Input((10, X_train_feat.shape[-1]))

    x = GraphConv(32, activation='relu')([inp_feat, inp_lap])
    x = GraphConv(16, activation='relu')([x, inp_lap])
    x = Flatten()(x)

    xx = LSTM(128, activation='relu', return_sequences=True)(inp_seq)
    xx = LSTM(32, activation='relu')(xx)

    x = Concatenate()([x,xx])
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1)(x)

    model = Model([inp_seq, inp_lap, inp_feat], out)
    model.compile(optimizer=opt, loss='mse', 
                  metrics=[tf.keras.metrics.RootMeanSquaredError()])

    return model

# %%
model = get_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 10, 7)]      0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10, 10)]     0
# __________________________________________________________________________________________________
# graph_conv (GraphConv)          (None, 10, 32)       256         input_3[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 14, 10)]     0
# __________________________________________________________________________________________________
# graph_conv_1 (GraphConv)        (None, 10, 16)       528         graph_conv[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 14, 128)      71168       input_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 160)          0           graph_conv_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 32)           20608       lstm[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 192)          0           flatten[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 192)          768         concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 192)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          24704       dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           4128        dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            33          dropout_1[0][0]
# ==================================================================================================
# Total params: 122,193
# Trainable params: 121,809
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
### TRAIN A MODEL FOR EACH STORES USING ALL THE DATA AVAILALBE FROM OTHER STORES ###

pred_valid_all = np.zeros(y_valid.shape)
pred_test_all = np.zeros(y_test.shape)

for store in range(10):

    print('-------', 'store', store, '-------')
    
    es = EarlyStopping(patience=5, verbose=1, min_delta=0.00001, monitor='loss', mode='auto', restore_best_weights=True)

    model = get_model()
    model.fit([X_train_seq, X_train_lap, X_train_feat], y_train[:,store], epochs=100, batch_size=256, 
              validation_data=([X_valid_seq, X_valid_lap, X_valid_feat], y_test[:,store]), callbacks=[es], verbose=2)

    pred_valid_all[:,store] = model.predict([X_valid_seq, X_valid_lap, X_valid_feat]).ravel()
    pred_test_all[:,store] = model.predict([X_test_seq, X_test_lap, X_test_feat]).ravel()

    
pred_valid_all = scaler_seq.inverse_transform(pred_valid_all)
reverse_valid = scaler_seq.inverse_transform(y_valid)
pred_test_all = scaler_seq.inverse_transform(pred_test_all)
reverse_test = scaler_seq.inverse_transform(y_test)
# Out:
# ------- store 0 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.4294 - root_mean_squared_error: 1.1956 - val_loss: 252.5874 - val_root_mean_squared_error: 15.8930
# Epoch 2/100
# 12/12 - 0s - loss: 0.5771 - root_mean_squared_error: 0.7597 - val_loss: 262.8425 - val_root_mean_squared_error: 16.2124
# Epoch 3/100
# 12/12 - 0s - loss: 0.4007 - root_mean_squared_error: 0.6330 - val_loss: 265.2742 - val_root_mean_squared_error: 16.2872
# Epoch 4/100
# 12/12 - 0s - loss: 0.3590 - root_mean_squared_error: 0.5991 - val_loss: 267.0169 - val_root_mean_squared_error: 16.3407
# Epoch 5/100
# 12/12 - 0s - loss: 0.3337 - root_mean_squared_error: 0.5777 - val_loss: 266.8295 - val_root_mean_squared_error: 16.3349
# Epoch 6/100
# 12/12 - 0s - loss: 0.3012 - root_mean_squared_error: 0.5488 - val_loss: 266.7841 - val_root_mean_squared_error: 16.3335
# Epoch 7/100
# 12/12 - 0s - loss: 0.2574 - root_mean_squared_error: 0.5074 - val_loss: 267.1160 - val_root_mean_squared_error: 16.3437
# Epoch 8/100
# 12/12 - 0s - loss: 0.2416 - root_mean_squared_error: 0.4915 - val_loss: 266.2664 - val_root_mean_squared_error: 16.3177
# Epoch 9/100
# 12/12 - 0s - loss: 0.2309 - root_mean_squared_error: 0.4805 - val_loss: 266.4769 - val_root_mean_squared_error: 16.3241
# Epoch 10/100
# 12/12 - 0s - loss: 0.2077 - root_mean_squared_error: 0.4558 - val_loss: 266.2282 - val_root_mean_squared_error: 16.3165
# Epoch 11/100
# 12/12 - 0s - loss: 0.2101 - root_mean_squared_error: 0.4584 - val_loss: 265.2277 - val_root_mean_squared_error: 16.2858
# Epoch 12/100
# 12/12 - 0s - loss: 0.1923 - root_mean_squared_error: 0.4385 - val_loss: 263.7493 - val_root_mean_squared_error: 16.2404
# Epoch 13/100
# 12/12 - 0s - loss: 0.1896 - root_mean_squared_error: 0.4354 - val_loss: 263.6653 - val_root_mean_squared_error: 16.2378
# Epoch 14/100
# 12/12 - 0s - loss: 0.1845 - root_mean_squared_error: 0.4296 - val_loss: 263.5793 - val_root_mean_squared_error: 16.2351
# Epoch 15/100
# 12/12 - 0s - loss: 0.1665 - root_mean_squared_error: 0.4081 - val_loss: 263.6816 - val_root_mean_squared_error: 16.2383
# Epoch 16/100
# 12/12 - 0s - loss: 0.1754 - root_mean_squared_error: 0.4188 - val_loss: 263.1305 - val_root_mean_squared_error: 16.2213
# Epoch 17/100
# 12/12 - 0s - loss: 0.1585 - root_mean_squared_error: 0.3981 - val_loss: 263.8864 - val_root_mean_squared_error: 16.2446
# Epoch 18/100
# 12/12 - 0s - loss: 0.1504 - root_mean_squared_error: 0.3878 - val_loss: 263.0851 - val_root_mean_squared_error: 16.2199
# Epoch 19/100
# 12/12 - 0s - loss: 0.1508 - root_mean_squared_error: 0.3883 - val_loss: 263.5637 - val_root_mean_squared_error: 16.2346
# Epoch 20/100
# 12/12 - 0s - loss: 0.1423 - root_mean_squared_error: 0.3772 - val_loss: 265.1813 - val_root_mean_squared_error: 16.2844
# Epoch 21/100
# 12/12 - 0s - loss: 0.1421 - root_mean_squared_error: 0.3770 - val_loss: 265.8709 - val_root_mean_squared_error: 16.3055
# Epoch 22/100
# 12/12 - 0s - loss: 0.1370 - root_mean_squared_error: 0.3701 - val_loss: 260.9064 - val_root_mean_squared_error: 16.1526
# Epoch 23/100
# 12/12 - 0s - loss: 0.1350 - root_mean_squared_error: 0.3675 - val_loss: 262.5078 - val_root_mean_squared_error: 16.2021
# Epoch 24/100
# 12/12 - 0s - loss: 0.1396 - root_mean_squared_error: 0.3737 - val_loss: 265.5653 - val_root_mean_squared_error: 16.2962
# Epoch 25/100
# 12/12 - 0s - loss: 0.1391 - root_mean_squared_error: 0.3729 - val_loss: 260.1164 - val_root_mean_squared_error: 16.1281
# Epoch 26/100
# 12/12 - 0s - loss: 0.1389 - root_mean_squared_error: 0.3726 - val_loss: 264.7362 - val_root_mean_squared_error: 16.2707
# Epoch 27/100
# 12/12 - 0s - loss: 0.1367 - root_mean_squared_error: 0.3697 - val_loss: 266.3556 - val_root_mean_squared_error: 16.3204
# Epoch 28/100
# 12/12 - 0s - loss: 0.1299 - root_mean_squared_error: 0.3604 - val_loss: 266.5953 - val_root_mean_squared_error: 16.3277
# Epoch 29/100
# 12/12 - 0s - loss: 0.1299 - root_mean_squared_error: 0.3604 - val_loss: 263.7529 - val_root_mean_squared_error: 16.2405
# Epoch 30/100
# 12/12 - 0s - loss: 0.1248 - root_mean_squared_error: 0.3532 - val_loss: 266.2896 - val_root_mean_squared_error: 16.3184
# Epoch 31/100
# 12/12 - 0s - loss: 0.1172 - root_mean_squared_error: 0.3423 - val_loss: 275.8361 - val_root_mean_squared_error: 16.6083
# Epoch 32/100
# 12/12 - 0s - loss: 0.1213 - root_mean_squared_error: 0.3483 - val_loss: 263.8087 - val_root_mean_squared_error: 16.2422
# Epoch 33/100
# 12/12 - 0s - loss: 0.1220 - root_mean_squared_error: 0.3492 - val_loss: 258.3157 - val_root_mean_squared_error: 16.0722
# Epoch 34/100
# 12/12 - 0s - loss: 0.1205 - root_mean_squared_error: 0.3471 - val_loss: 262.8269 - val_root_mean_squared_error: 16.2119
# Epoch 35/100
# 12/12 - 0s - loss: 0.1175 - root_mean_squared_error: 0.3428 - val_loss: 263.8287 - val_root_mean_squared_error: 16.2428
# Epoch 36/100
# 12/12 - 0s - loss: 0.1179 - root_mean_squared_error: 0.3433 - val_loss: 263.4147 - val_root_mean_squared_error: 16.2301
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# ------- store 1 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.4117 - root_mean_squared_error: 1.1881 - val_loss: 325.8403 - val_root_mean_squared_error: 18.0510
# Epoch 2/100
# 12/12 - 0s - loss: 0.5469 - root_mean_squared_error: 0.7395 - val_loss: 242.1773 - val_root_mean_squared_error: 15.5620
# Epoch 3/100
# 12/12 - 0s - loss: 0.4109 - root_mean_squared_error: 0.6410 - val_loss: 325.9216 - val_root_mean_squared_error: 18.0533
# Epoch 4/100
# 12/12 - 0s - loss: 0.3520 - root_mean_squared_error: 0.5933 - val_loss: 330.7367 - val_root_mean_squared_error: 18.1862
# Epoch 5/100
# 12/12 - 0s - loss: 0.3127 - root_mean_squared_error: 0.5592 - val_loss: 329.5334 - val_root_mean_squared_error: 18.1531
# Epoch 6/100
# 12/12 - 0s - loss: 0.2881 - root_mean_squared_error: 0.5368 - val_loss: 333.0831 - val_root_mean_squared_error: 18.2506
# Epoch 7/100
# 12/12 - 0s - loss: 0.2519 - root_mean_squared_error: 0.5019 - val_loss: 347.0146 - val_root_mean_squared_error: 18.6283
# Epoch 8/100
# 12/12 - 0s - loss: 0.2341 - root_mean_squared_error: 0.4838 - val_loss: 340.0521 - val_root_mean_squared_error: 18.4405
# Epoch 9/100
# 12/12 - 0s - loss: 0.2114 - root_mean_squared_error: 0.4598 - val_loss: 346.7803 - val_root_mean_squared_error: 18.6220
# Epoch 10/100
# 12/12 - 0s - loss: 0.1981 - root_mean_squared_error: 0.4451 - val_loss: 349.3414 - val_root_mean_squared_error: 18.6907
# Epoch 11/100
# 12/12 - 0s - loss: 0.1878 - root_mean_squared_error: 0.4334 - val_loss: 358.5504 - val_root_mean_squared_error: 18.9354
# Epoch 12/100
# 12/12 - 1s - loss: 0.1765 - root_mean_squared_error: 0.4202 - val_loss: 361.1340 - val_root_mean_squared_error: 19.0035
# Epoch 13/100
# 12/12 - 1s - loss: 0.1704 - root_mean_squared_error: 0.4128 - val_loss: 365.3251 - val_root_mean_squared_error: 19.1135
# Epoch 14/100
# 12/12 - 0s - loss: 0.1560 - root_mean_squared_error: 0.3950 - val_loss: 377.6624 - val_root_mean_squared_error: 19.4335
# Epoch 15/100
# 12/12 - 0s - loss: 0.1625 - root_mean_squared_error: 0.4031 - val_loss: 382.6516 - val_root_mean_squared_error: 19.5615
# Epoch 16/100
# 12/12 - 0s - loss: 0.1434 - root_mean_squared_error: 0.3787 - val_loss: 380.5270 - val_root_mean_squared_error: 19.5071
# Epoch 17/100
# 12/12 - 0s - loss: 0.1371 - root_mean_squared_error: 0.3702 - val_loss: 379.1310 - val_root_mean_squared_error: 19.4713
# Epoch 18/100
# 12/12 - 0s - loss: 0.1446 - root_mean_squared_error: 0.3803 - val_loss: 383.5411 - val_root_mean_squared_error: 19.5842
# Epoch 19/100
# 12/12 - 1s - loss: 0.1363 - root_mean_squared_error: 0.3692 - val_loss: 406.2398 - val_root_mean_squared_error: 20.1554
# Epoch 20/100
# 12/12 - 1s - loss: 0.1329 - root_mean_squared_error: 0.3646 - val_loss: 400.1658 - val_root_mean_squared_error: 20.0041
# Epoch 21/100
# 12/12 - 0s - loss: 0.1290 - root_mean_squared_error: 0.3592 - val_loss: 420.6746 - val_root_mean_squared_error: 20.5104
# Epoch 22/100
# 12/12 - 0s - loss: 0.1285 - root_mean_squared_error: 0.3584 - val_loss: 436.0367 - val_root_mean_squared_error: 20.8815
# Epoch 23/100
# 12/12 - 0s - loss: 0.1271 - root_mean_squared_error: 0.3565 - val_loss: 431.5897 - val_root_mean_squared_error: 20.7747
# Epoch 24/100
# 12/12 - 0s - loss: 0.1267 - root_mean_squared_error: 0.3560 - val_loss: 416.5847 - val_root_mean_squared_error: 20.4104
# Epoch 25/100
# 12/12 - 0s - loss: 0.1255 - root_mean_squared_error: 0.3543 - val_loss: 452.8928 - val_root_mean_squared_error: 21.2813
# Epoch 26/100
# 12/12 - 0s - loss: 0.1215 - root_mean_squared_error: 0.3485 - val_loss: 423.6454 - val_root_mean_squared_error: 20.5826
# Epoch 27/100
# 12/12 - 0s - loss: 0.1222 - root_mean_squared_error: 0.3495 - val_loss: 401.1530 - val_root_mean_squared_error: 20.0288
# Epoch 28/100
# 12/12 - 0s - loss: 0.1195 - root_mean_squared_error: 0.3457 - val_loss: 419.0444 - val_root_mean_squared_error: 20.4706
# Epoch 29/100
# 12/12 - 0s - loss: 0.1179 - root_mean_squared_error: 0.3434 - val_loss: 442.3714 - val_root_mean_squared_error: 21.0326
# Epoch 30/100
# 12/12 - 0s - loss: 0.1151 - root_mean_squared_error: 0.3392 - val_loss: 417.4642 - val_root_mean_squared_error: 20.4319
# Epoch 31/100
# 12/12 - 0s - loss: 0.1104 - root_mean_squared_error: 0.3323 - val_loss: 426.7427 - val_root_mean_squared_error: 20.6578
# Epoch 32/100
# 12/12 - 0s - loss: 0.1135 - root_mean_squared_error: 0.3369 - val_loss: 421.8938 - val_root_mean_squared_error: 20.5401
# Epoch 33/100
# 12/12 - 0s - loss: 0.1098 - root_mean_squared_error: 0.3314 - val_loss: 452.8865 - val_root_mean_squared_error: 21.2811
# Epoch 34/100
# 12/12 - 0s - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 426.6670 - val_root_mean_squared_error: 20.6559
# Epoch 35/100
# 12/12 - 0s - loss: 0.1129 - root_mean_squared_error: 0.3360 - val_loss: 457.0334 - val_root_mean_squared_error: 21.3783
# Epoch 36/100
# 12/12 - 0s - loss: 0.1097 - root_mean_squared_error: 0.3312 - val_loss: 500.6855 - val_root_mean_squared_error: 22.3760
# Epoch 37/100
# 12/12 - 0s - loss: 0.1036 - root_mean_squared_error: 0.3219 - val_loss: 470.8202 - val_root_mean_squared_error: 21.6984
# Epoch 38/100
# 12/12 - 1s - loss: 0.1043 - root_mean_squared_error: 0.3230 - val_loss: 493.6362 - val_root_mean_squared_error: 22.2179
# Epoch 39/100
# 12/12 - 1s - loss: 0.1076 - root_mean_squared_error: 0.3281 - val_loss: 454.3356 - val_root_mean_squared_error: 21.3151
# Epoch 40/100
# 12/12 - 0s - loss: 0.1044 - root_mean_squared_error: 0.3230 - val_loss: 513.1090 - val_root_mean_squared_error: 22.6519
# Epoch 41/100
# 12/12 - 1s - loss: 0.0958 - root_mean_squared_error: 0.3096 - val_loss: 437.9247 - val_root_mean_squared_error: 20.9267
# Epoch 42/100
# 12/12 - 0s - loss: 0.0995 - root_mean_squared_error: 0.3155 - val_loss: 449.5316 - val_root_mean_squared_error: 21.2022
# Epoch 43/100
# 12/12 - 0s - loss: 0.0921 - root_mean_squared_error: 0.3035 - val_loss: 496.0195 - val_root_mean_squared_error: 22.2715
# Epoch 44/100
# 12/12 - 0s - loss: 0.1011 - root_mean_squared_error: 0.3180 - val_loss: 488.9762 - val_root_mean_squared_error: 22.1128
# Epoch 45/100
# 12/12 - 0s - loss: 0.0968 - root_mean_squared_error: 0.3111 - val_loss: 448.2688 - val_root_mean_squared_error: 21.1724
# Epoch 46/100
# 12/12 - 0s - loss: 0.0925 - root_mean_squared_error: 0.3042 - val_loss: 443.7441 - val_root_mean_squared_error: 21.0652
# Epoch 47/100
# 12/12 - 0s - loss: 0.0973 - root_mean_squared_error: 0.3119 - val_loss: 422.9590 - val_root_mean_squared_error: 20.5660
# Epoch 48/100
# 12/12 - 0s - loss: 0.0982 - root_mean_squared_error: 0.3133 - val_loss: 459.4087 - val_root_mean_squared_error: 21.4338
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# ------- store 2 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.1554 - root_mean_squared_error: 1.0749 - val_loss: 97.6276 - val_root_mean_squared_error: 9.8807
# Epoch 2/100
# 12/12 - 0s - loss: 0.4831 - root_mean_squared_error: 0.6951 - val_loss: 97.8729 - val_root_mean_squared_error: 9.8931
# Epoch 3/100
# 12/12 - 0s - loss: 0.3399 - root_mean_squared_error: 0.5830 - val_loss: 98.6584 - val_root_mean_squared_error: 9.9327
# Epoch 4/100
# 12/12 - 0s - loss: 0.2802 - root_mean_squared_error: 0.5294 - val_loss: 99.2241 - val_root_mean_squared_error: 9.9611
# Epoch 5/100
# 12/12 - 0s - loss: 0.2359 - root_mean_squared_error: 0.4857 - val_loss: 99.2050 - val_root_mean_squared_error: 9.9602
# Epoch 6/100
# 12/12 - 0s - loss: 0.2164 - root_mean_squared_error: 0.4652 - val_loss: 99.2220 - val_root_mean_squared_error: 9.9610
# Epoch 7/100
# 12/12 - 0s - loss: 0.1968 - root_mean_squared_error: 0.4436 - val_loss: 99.0123 - val_root_mean_squared_error: 9.9505
# Epoch 8/100
# 12/12 - 0s - loss: 0.1910 - root_mean_squared_error: 0.4370 - val_loss: 98.7340 - val_root_mean_squared_error: 9.9365
# Epoch 9/100
# 12/12 - 0s - loss: 0.1722 - root_mean_squared_error: 0.4149 - val_loss: 98.6395 - val_root_mean_squared_error: 9.9317
# Epoch 10/100
# 12/12 - 0s - loss: 0.1703 - root_mean_squared_error: 0.4127 - val_loss: 98.6172 - val_root_mean_squared_error: 9.9306
# Epoch 11/100
# 12/12 - 0s - loss: 0.1589 - root_mean_squared_error: 0.3986 - val_loss: 97.6895 - val_root_mean_squared_error: 9.8838
# Epoch 12/100
# 12/12 - 0s - loss: 0.1630 - root_mean_squared_error: 0.4038 - val_loss: 98.2747 - val_root_mean_squared_error: 9.9134
# Epoch 13/100
# 12/12 - 0s - loss: 0.1604 - root_mean_squared_error: 0.4005 - val_loss: 98.4105 - val_root_mean_squared_error: 9.9202
# Epoch 14/100
# 12/12 - 0s - loss: 0.1450 - root_mean_squared_error: 0.3808 - val_loss: 98.3121 - val_root_mean_squared_error: 9.9152
# Epoch 15/100
# 12/12 - 0s - loss: 0.1415 - root_mean_squared_error: 0.3761 - val_loss: 97.6663 - val_root_mean_squared_error: 9.8826
# Epoch 16/100
# 12/12 - 0s - loss: 0.1335 - root_mean_squared_error: 0.3654 - val_loss: 97.6346 - val_root_mean_squared_error: 9.8810
# Epoch 17/100
# 12/12 - 0s - loss: 0.1425 - root_mean_squared_error: 0.3775 - val_loss: 96.9566 - val_root_mean_squared_error: 9.8467
# Epoch 18/100
# 12/12 - 0s - loss: 0.1241 - root_mean_squared_error: 0.3523 - val_loss: 97.8105 - val_root_mean_squared_error: 9.8899
# Epoch 19/100
# 12/12 - 1s - loss: 0.1254 - root_mean_squared_error: 0.3541 - val_loss: 98.2226 - val_root_mean_squared_error: 9.9107
# Epoch 20/100
# 12/12 - 0s - loss: 0.1239 - root_mean_squared_error: 0.3520 - val_loss: 97.0715 - val_root_mean_squared_error: 9.8525
# Epoch 21/100
# 12/12 - 0s - loss: 0.1109 - root_mean_squared_error: 0.3330 - val_loss: 97.1022 - val_root_mean_squared_error: 9.8540
# Epoch 22/100
# 12/12 - 0s - loss: 0.1127 - root_mean_squared_error: 0.3357 - val_loss: 98.4002 - val_root_mean_squared_error: 9.9197
# Epoch 23/100
# 12/12 - 1s - loss: 0.1122 - root_mean_squared_error: 0.3350 - val_loss: 97.4249 - val_root_mean_squared_error: 9.8704
# Epoch 24/100
# 12/12 - 0s - loss: 0.1075 - root_mean_squared_error: 0.3278 - val_loss: 97.2488 - val_root_mean_squared_error: 9.8615
# Epoch 25/100
# 12/12 - 1s - loss: 0.1053 - root_mean_squared_error: 0.3245 - val_loss: 97.1250 - val_root_mean_squared_error: 9.8552
# Epoch 26/100
# 12/12 - 0s - loss: 0.1050 - root_mean_squared_error: 0.3241 - val_loss: 98.6891 - val_root_mean_squared_error: 9.9342
# Epoch 27/100
# 12/12 - 0s - loss: 0.0999 - root_mean_squared_error: 0.3161 - val_loss: 98.0386 - val_root_mean_squared_error: 9.9014
# Epoch 28/100
# 12/12 - 0s - loss: 0.1005 - root_mean_squared_error: 0.3170 - val_loss: 98.4598 - val_root_mean_squared_error: 9.9227
# Epoch 29/100
# 12/12 - 1s - loss: 0.1024 - root_mean_squared_error: 0.3200 - val_loss: 97.1191 - val_root_mean_squared_error: 9.8549
# Epoch 30/100
# 12/12 - 1s - loss: 0.0979 - root_mean_squared_error: 0.3129 - val_loss: 97.4974 - val_root_mean_squared_error: 9.8741
# Epoch 31/100
# 12/12 - 1s - loss: 0.0917 - root_mean_squared_error: 0.3029 - val_loss: 95.2843 - val_root_mean_squared_error: 9.7614
# Epoch 32/100
# 12/12 - 0s - loss: 0.0924 - root_mean_squared_error: 0.3039 - val_loss: 95.9528 - val_root_mean_squared_error: 9.7955
# Epoch 33/100
# 12/12 - 0s - loss: 0.0842 - root_mean_squared_error: 0.2901 - val_loss: 94.8495 - val_root_mean_squared_error: 9.7391
# Epoch 34/100
# 12/12 - 0s - loss: 0.0841 - root_mean_squared_error: 0.2901 - val_loss: 96.2061 - val_root_mean_squared_error: 9.8085
# Epoch 35/100
# 12/12 - 0s - loss: 0.0942 - root_mean_squared_error: 0.3069 - val_loss: 95.5284 - val_root_mean_squared_error: 9.7739
# Epoch 36/100
# 12/12 - 0s - loss: 0.0885 - root_mean_squared_error: 0.2975 - val_loss: 94.6997 - val_root_mean_squared_error: 9.7314
# Epoch 37/100
# 12/12 - 0s - loss: 0.0983 - root_mean_squared_error: 0.3136 - val_loss: 95.5873 - val_root_mean_squared_error: 9.7769
# Epoch 38/100
# 12/12 - 0s - loss: 0.0938 - root_mean_squared_error: 0.3063 - val_loss: 97.3188 - val_root_mean_squared_error: 9.8650
# Epoch 39/100
# 12/12 - 0s - loss: 0.0934 - root_mean_squared_error: 0.3056 - val_loss: 94.4763 - val_root_mean_squared_error: 9.7199
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# ------- store 3 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.2548 - root_mean_squared_error: 1.1202 - val_loss: 12.1245 - val_root_mean_squared_error: 3.4820
# Epoch 2/100
# 12/12 - 0s - loss: 0.5833 - root_mean_squared_error: 0.7637 - val_loss: 12.2044 - val_root_mean_squared_error: 3.4935
# Epoch 3/100
# 12/12 - 1s - loss: 0.4220 - root_mean_squared_error: 0.6496 - val_loss: 15.6140 - val_root_mean_squared_error: 3.9515
# Epoch 4/100
# 12/12 - 1s - loss: 0.3394 - root_mean_squared_error: 0.5825 - val_loss: 24.1909 - val_root_mean_squared_error: 4.9184
# Epoch 5/100
# 12/12 - 1s - loss: 0.2956 - root_mean_squared_error: 0.5437 - val_loss: 18.8440 - val_root_mean_squared_error: 4.3410
# Epoch 6/100
# 12/12 - 1s - loss: 0.2699 - root_mean_squared_error: 0.5195 - val_loss: 16.2623 - val_root_mean_squared_error: 4.0327
# Epoch 7/100
# 12/12 - 1s - loss: 0.2512 - root_mean_squared_error: 0.5012 - val_loss: 16.0182 - val_root_mean_squared_error: 4.0023
# Epoch 8/100
# 12/12 - 1s - loss: 0.2483 - root_mean_squared_error: 0.4983 - val_loss: 17.7484 - val_root_mean_squared_error: 4.2129
# Epoch 9/100
# 12/12 - 1s - loss: 0.2203 - root_mean_squared_error: 0.4694 - val_loss: 17.7622 - val_root_mean_squared_error: 4.2145
# Epoch 10/100
# 12/12 - 1s - loss: 0.2049 - root_mean_squared_error: 0.4527 - val_loss: 21.3868 - val_root_mean_squared_error: 4.6246
# Epoch 11/100
# 12/12 - 1s - loss: 0.2018 - root_mean_squared_error: 0.4492 - val_loss: 17.5696 - val_root_mean_squared_error: 4.1916
# Epoch 12/100
# 12/12 - 1s - loss: 0.1951 - root_mean_squared_error: 0.4417 - val_loss: 17.5002 - val_root_mean_squared_error: 4.1833
# Epoch 13/100
# 12/12 - 1s - loss: 0.1684 - root_mean_squared_error: 0.4104 - val_loss: 17.3591 - val_root_mean_squared_error: 4.1664
# Epoch 14/100
# 12/12 - 1s - loss: 0.1729 - root_mean_squared_error: 0.4158 - val_loss: 16.1032 - val_root_mean_squared_error: 4.0129
# Epoch 15/100
# 12/12 - 0s - loss: 0.1665 - root_mean_squared_error: 0.4080 - val_loss: 17.7653 - val_root_mean_squared_error: 4.2149
# Epoch 16/100
# 12/12 - 0s - loss: 0.1542 - root_mean_squared_error: 0.3927 - val_loss: 19.0682 - val_root_mean_squared_error: 4.3667
# Epoch 17/100
# 12/12 - 0s - loss: 0.1512 - root_mean_squared_error: 0.3889 - val_loss: 19.5296 - val_root_mean_squared_error: 4.4192
# Epoch 18/100
# 12/12 - 0s - loss: 0.1491 - root_mean_squared_error: 0.3862 - val_loss: 21.5995 - val_root_mean_squared_error: 4.6475
# Epoch 19/100
# 12/12 - 0s - loss: 0.1483 - root_mean_squared_error: 0.3850 - val_loss: 18.7590 - val_root_mean_squared_error: 4.3312
# Epoch 20/100
# 12/12 - 1s - loss: 0.1445 - root_mean_squared_error: 0.3801 - val_loss: 23.3434 - val_root_mean_squared_error: 4.8315
# Epoch 21/100
# 12/12 - 1s - loss: 0.1392 - root_mean_squared_error: 0.3731 - val_loss: 24.8438 - val_root_mean_squared_error: 4.9844
# Epoch 22/100
# 12/12 - 0s - loss: 0.1392 - root_mean_squared_error: 0.3731 - val_loss: 28.2542 - val_root_mean_squared_error: 5.3155
# Epoch 23/100
# 12/12 - 0s - loss: 0.1305 - root_mean_squared_error: 0.3613 - val_loss: 26.0504 - val_root_mean_squared_error: 5.1040
# Epoch 24/100
# 12/12 - 1s - loss: 0.1246 - root_mean_squared_error: 0.3530 - val_loss: 22.9480 - val_root_mean_squared_error: 4.7904
# Epoch 25/100
# 12/12 - 0s - loss: 0.1341 - root_mean_squared_error: 0.3662 - val_loss: 21.4369 - val_root_mean_squared_error: 4.6300
# Epoch 26/100
# 12/12 - 0s - loss: 0.1377 - root_mean_squared_error: 0.3711 - val_loss: 22.2125 - val_root_mean_squared_error: 4.7130
# Epoch 27/100
# 12/12 - 0s - loss: 0.1299 - root_mean_squared_error: 0.3604 - val_loss: 22.2103 - val_root_mean_squared_error: 4.7128
# Epoch 28/100
# 12/12 - 0s - loss: 0.1215 - root_mean_squared_error: 0.3486 - val_loss: 22.5155 - val_root_mean_squared_error: 4.7450
# Epoch 29/100
# 12/12 - 0s - loss: 0.1162 - root_mean_squared_error: 0.3409 - val_loss: 24.0768 - val_root_mean_squared_error: 4.9068
# Epoch 30/100
# 12/12 - 0s - loss: 0.1233 - root_mean_squared_error: 0.3512 - val_loss: 21.0117 - val_root_mean_squared_error: 4.5839
# Epoch 31/100
# 12/12 - 0s - loss: 0.1149 - root_mean_squared_error: 0.3389 - val_loss: 21.4412 - val_root_mean_squared_error: 4.6305
# Epoch 32/100
# 12/12 - 1s - loss: 0.1115 - root_mean_squared_error: 0.3338 - val_loss: 20.0512 - val_root_mean_squared_error: 4.4779
# Epoch 33/100
# 12/12 - 1s - loss: 0.1094 - root_mean_squared_error: 0.3308 - val_loss: 17.0125 - val_root_mean_squared_error: 4.1246
# Epoch 34/100
# 12/12 - 1s - loss: 0.1143 - root_mean_squared_error: 0.3381 - val_loss: 20.3555 - val_root_mean_squared_error: 4.5117
# Epoch 35/100
# 12/12 - 0s - loss: 0.1152 - root_mean_squared_error: 0.3394 - val_loss: 26.7019 - val_root_mean_squared_error: 5.1674
# Epoch 36/100
# 12/12 - 0s - loss: 0.1088 - root_mean_squared_error: 0.3299 - val_loss: 23.1977 - val_root_mean_squared_error: 4.8164
# Epoch 37/100
# 12/12 - 0s - loss: 0.1164 - root_mean_squared_error: 0.3412 - val_loss: 26.3870 - val_root_mean_squared_error: 5.1368
# Epoch 38/100
# 12/12 - 0s - loss: 0.1164 - root_mean_squared_error: 0.3412 - val_loss: 22.7079 - val_root_mean_squared_error: 4.7653
# Epoch 39/100
# 12/12 - 0s - loss: 0.1018 - root_mean_squared_error: 0.3191 - val_loss: 22.2363 - val_root_mean_squared_error: 4.7155
# Epoch 40/100
# 12/12 - 0s - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 26.3607 - val_root_mean_squared_error: 5.1343
# Epoch 41/100
# 12/12 - 0s - loss: 0.1040 - root_mean_squared_error: 0.3225 - val_loss: 27.4503 - val_root_mean_squared_error: 5.2393
# Epoch 42/100
# 12/12 - 0s - loss: 0.1097 - root_mean_squared_error: 0.3313 - val_loss: 24.2217 - val_root_mean_squared_error: 4.9216
# Epoch 43/100
# 12/12 - 0s - loss: 0.1027 - root_mean_squared_error: 0.3205 - val_loss: 22.0636 - val_root_mean_squared_error: 4.6972
# Epoch 44/100
# 12/12 - 0s - loss: 0.1028 - root_mean_squared_error: 0.3206 - val_loss: 22.4322 - val_root_mean_squared_error: 4.7363
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# ------- store 4 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.1904 - root_mean_squared_error: 1.0910 - val_loss: 15.1495 - val_root_mean_squared_error: 3.8922
# Epoch 2/100
# 12/12 - 0s - loss: 0.5314 - root_mean_squared_error: 0.7290 - val_loss: 14.9936 - val_root_mean_squared_error: 3.8722
# Epoch 3/100
# 12/12 - 0s - loss: 0.3809 - root_mean_squared_error: 0.6171 - val_loss: 15.1787 - val_root_mean_squared_error: 3.8960
# Epoch 4/100
# 12/12 - 0s - loss: 0.2877 - root_mean_squared_error: 0.5364 - val_loss: 15.2454 - val_root_mean_squared_error: 3.9045
# Epoch 5/100
# 12/12 - 0s - loss: 0.2563 - root_mean_squared_error: 0.5063 - val_loss: 15.3287 - val_root_mean_squared_error: 3.9152
# Epoch 6/100
# 12/12 - 0s - loss: 0.2254 - root_mean_squared_error: 0.4748 - val_loss: 15.5107 - val_root_mean_squared_error: 3.9384
# Epoch 7/100
# 12/12 - 1s - loss: 0.2028 - root_mean_squared_error: 0.4503 - val_loss: 15.5899 - val_root_mean_squared_error: 3.9484
# Epoch 8/100
# 12/12 - 0s - loss: 0.2032 - root_mean_squared_error: 0.4508 - val_loss: 15.7542 - val_root_mean_squared_error: 3.9692
# Epoch 9/100
# 12/12 - 0s - loss: 0.1795 - root_mean_squared_error: 0.4237 - val_loss: 15.8773 - val_root_mean_squared_error: 3.9846
# Epoch 10/100
# 12/12 - 0s - loss: 0.1795 - root_mean_squared_error: 0.4237 - val_loss: 16.5564 - val_root_mean_squared_error: 4.0690
# Epoch 11/100
# 12/12 - 0s - loss: 0.1650 - root_mean_squared_error: 0.4062 - val_loss: 16.5070 - val_root_mean_squared_error: 4.0629
# Epoch 12/100
# 12/12 - 0s - loss: 0.1609 - root_mean_squared_error: 0.4011 - val_loss: 17.4594 - val_root_mean_squared_error: 4.1784
# Epoch 13/100
# 12/12 - 0s - loss: 0.1530 - root_mean_squared_error: 0.3912 - val_loss: 16.8779 - val_root_mean_squared_error: 4.1083
# Epoch 14/100
# 12/12 - 0s - loss: 0.1376 - root_mean_squared_error: 0.3709 - val_loss: 17.2223 - val_root_mean_squared_error: 4.1500
# Epoch 15/100
# 12/12 - 0s - loss: 0.1462 - root_mean_squared_error: 0.3824 - val_loss: 18.0341 - val_root_mean_squared_error: 4.2467
# Epoch 16/100
# 12/12 - 1s - loss: 0.1361 - root_mean_squared_error: 0.3689 - val_loss: 17.4074 - val_root_mean_squared_error: 4.1722
# Epoch 17/100
# 12/12 - 1s - loss: 0.1330 - root_mean_squared_error: 0.3647 - val_loss: 17.8091 - val_root_mean_squared_error: 4.2201
# Epoch 18/100
# 12/12 - 0s - loss: 0.1255 - root_mean_squared_error: 0.3543 - val_loss: 18.7584 - val_root_mean_squared_error: 4.3311
# Epoch 19/100
# 12/12 - 0s - loss: 0.1225 - root_mean_squared_error: 0.3500 - val_loss: 17.7439 - val_root_mean_squared_error: 4.2124
# Epoch 20/100
# 12/12 - 0s - loss: 0.1252 - root_mean_squared_error: 0.3538 - val_loss: 18.6264 - val_root_mean_squared_error: 4.3158
# Epoch 21/100
# 12/12 - 1s - loss: 0.1166 - root_mean_squared_error: 0.3415 - val_loss: 19.5150 - val_root_mean_squared_error: 4.4176
# Epoch 22/100
# 12/12 - 0s - loss: 0.1233 - root_mean_squared_error: 0.3512 - val_loss: 18.3559 - val_root_mean_squared_error: 4.2844
# Epoch 23/100
# 12/12 - 0s - loss: 0.1152 - root_mean_squared_error: 0.3394 - val_loss: 18.2581 - val_root_mean_squared_error: 4.2729
# Epoch 24/100
# 12/12 - 0s - loss: 0.1076 - root_mean_squared_error: 0.3280 - val_loss: 17.4899 - val_root_mean_squared_error: 4.1821
# Epoch 25/100
# 12/12 - 0s - loss: 0.1171 - root_mean_squared_error: 0.3422 - val_loss: 17.4110 - val_root_mean_squared_error: 4.1726
# Epoch 26/100
# 12/12 - 0s - loss: 0.1210 - root_mean_squared_error: 0.3479 - val_loss: 18.7771 - val_root_mean_squared_error: 4.3333
# Epoch 27/100
# 12/12 - 0s - loss: 0.1103 - root_mean_squared_error: 0.3321 - val_loss: 18.9674 - val_root_mean_squared_error: 4.3552
# Epoch 28/100
# 12/12 - 0s - loss: 0.1070 - root_mean_squared_error: 0.3271 - val_loss: 19.0634 - val_root_mean_squared_error: 4.3662
# Epoch 29/100
# 12/12 - 0s - loss: 0.1004 - root_mean_squared_error: 0.3168 - val_loss: 18.3608 - val_root_mean_squared_error: 4.2849
# Epoch 30/100
# 12/12 - 0s - loss: 0.1024 - root_mean_squared_error: 0.3199 - val_loss: 17.1965 - val_root_mean_squared_error: 4.1469
# Epoch 31/100
# 12/12 - 0s - loss: 0.1013 - root_mean_squared_error: 0.3183 - val_loss: 18.7317 - val_root_mean_squared_error: 4.3280
# Epoch 32/100
# 12/12 - 0s - loss: 0.1119 - root_mean_squared_error: 0.3345 - val_loss: 17.8324 - val_root_mean_squared_error: 4.2228
# Epoch 33/100
# 12/12 - 0s - loss: 0.0997 - root_mean_squared_error: 0.3158 - val_loss: 17.5517 - val_root_mean_squared_error: 4.1895
# Epoch 34/100
# 12/12 - 0s - loss: 0.0909 - root_mean_squared_error: 0.3015 - val_loss: 17.0597 - val_root_mean_squared_error: 4.1303
# Epoch 35/100
# 12/12 - 0s - loss: 0.0984 - root_mean_squared_error: 0.3137 - val_loss: 18.3656 - val_root_mean_squared_error: 4.2855
# Epoch 36/100
# 12/12 - 0s - loss: 0.0940 - root_mean_squared_error: 0.3066 - val_loss: 16.8496 - val_root_mean_squared_error: 4.1048
# Epoch 37/100
# 12/12 - 0s - loss: 0.0969 - root_mean_squared_error: 0.3114 - val_loss: 18.4296 - val_root_mean_squared_error: 4.2930
# Epoch 38/100
# 12/12 - 0s - loss: 0.0982 - root_mean_squared_error: 0.3133 - val_loss: 17.9581 - val_root_mean_squared_error: 4.2377
# Epoch 39/100
# 12/12 - 0s - loss: 0.0918 - root_mean_squared_error: 0.3030 - val_loss: 17.1686 - val_root_mean_squared_error: 4.1435
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# ------- store 5 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.1558 - root_mean_squared_error: 1.0751 - val_loss: 1.2662 - val_root_mean_squared_error: 1.1253
# Epoch 2/100
# 12/12 - 0s - loss: 0.4977 - root_mean_squared_error: 0.7054 - val_loss: 1.2369 - val_root_mean_squared_error: 1.1122
# Epoch 3/100
# 12/12 - 1s - loss: 0.3530 - root_mean_squared_error: 0.5941 - val_loss: 1.3766 - val_root_mean_squared_error: 1.1733
# Epoch 4/100
# 12/12 - 0s - loss: 0.2810 - root_mean_squared_error: 0.5301 - val_loss: 1.5055 - val_root_mean_squared_error: 1.2270
# Epoch 5/100
# 12/12 - 0s - loss: 0.2407 - root_mean_squared_error: 0.4906 - val_loss: 1.6017 - val_root_mean_squared_error: 1.2656
# Epoch 6/100
# 12/12 - 0s - loss: 0.2188 - root_mean_squared_error: 0.4677 - val_loss: 1.5166 - val_root_mean_squared_error: 1.2315
# Epoch 7/100
# 12/12 - 1s - loss: 0.1996 - root_mean_squared_error: 0.4468 - val_loss: 1.4499 - val_root_mean_squared_error: 1.2041
# Epoch 8/100
# 12/12 - 0s - loss: 0.1959 - root_mean_squared_error: 0.4426 - val_loss: 1.4861 - val_root_mean_squared_error: 1.2190
# Epoch 9/100
# 12/12 - 0s - loss: 0.1656 - root_mean_squared_error: 0.4070 - val_loss: 1.5798 - val_root_mean_squared_error: 1.2569
# Epoch 10/100
# 12/12 - 0s - loss: 0.1612 - root_mean_squared_error: 0.4014 - val_loss: 2.0329 - val_root_mean_squared_error: 1.4258
# Epoch 11/100
# 12/12 - 0s - loss: 0.1554 - root_mean_squared_error: 0.3942 - val_loss: 2.1320 - val_root_mean_squared_error: 1.4601
# Epoch 12/100
# 12/12 - 0s - loss: 0.1513 - root_mean_squared_error: 0.3890 - val_loss: 2.7642 - val_root_mean_squared_error: 1.6626
# Epoch 13/100
# 12/12 - 0s - loss: 0.1409 - root_mean_squared_error: 0.3754 - val_loss: 2.2894 - val_root_mean_squared_error: 1.5131
# Epoch 14/100
# 12/12 - 1s - loss: 0.1330 - root_mean_squared_error: 0.3646 - val_loss: 2.0473 - val_root_mean_squared_error: 1.4308
# Epoch 15/100
# 12/12 - 0s - loss: 0.1402 - root_mean_squared_error: 0.3745 - val_loss: 2.4292 - val_root_mean_squared_error: 1.5586
# Epoch 16/100
# 12/12 - 0s - loss: 0.1302 - root_mean_squared_error: 0.3609 - val_loss: 2.4718 - val_root_mean_squared_error: 1.5722
# Epoch 17/100
# 12/12 - 0s - loss: 0.1347 - root_mean_squared_error: 0.3670 - val_loss: 2.5771 - val_root_mean_squared_error: 1.6053
# Epoch 18/100
# 12/12 - 0s - loss: 0.1184 - root_mean_squared_error: 0.3441 - val_loss: 2.9196 - val_root_mean_squared_error: 1.7087
# Epoch 19/100
# 12/12 - 0s - loss: 0.1162 - root_mean_squared_error: 0.3409 - val_loss: 2.5536 - val_root_mean_squared_error: 1.5980
# Epoch 20/100
# 12/12 - 0s - loss: 0.1146 - root_mean_squared_error: 0.3386 - val_loss: 2.5787 - val_root_mean_squared_error: 1.6058
# Epoch 21/100
# 12/12 - 0s - loss: 0.1118 - root_mean_squared_error: 0.3343 - val_loss: 2.9040 - val_root_mean_squared_error: 1.7041
# Epoch 22/100
# 12/12 - 0s - loss: 0.1105 - root_mean_squared_error: 0.3325 - val_loss: 2.4733 - val_root_mean_squared_error: 1.5727
# Epoch 23/100
# 12/12 - 0s - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 2.5709 - val_root_mean_squared_error: 1.6034
# Epoch 24/100
# 12/12 - 0s - loss: 0.0998 - root_mean_squared_error: 0.3160 - val_loss: 2.5817 - val_root_mean_squared_error: 1.6068
# Epoch 25/100
# 12/12 - 0s - loss: 0.1012 - root_mean_squared_error: 0.3181 - val_loss: 2.6080 - val_root_mean_squared_error: 1.6149
# Epoch 26/100
# 12/12 - 0s - loss: 0.1148 - root_mean_squared_error: 0.3389 - val_loss: 3.4639 - val_root_mean_squared_error: 1.8611
# Epoch 27/100
# 12/12 - 0s - loss: 0.1032 - root_mean_squared_error: 0.3213 - val_loss: 3.1084 - val_root_mean_squared_error: 1.7631
# Epoch 28/100
# 12/12 - 0s - loss: 0.0964 - root_mean_squared_error: 0.3104 - val_loss: 2.7986 - val_root_mean_squared_error: 1.6729
# Epoch 29/100
# 12/12 - 0s - loss: 0.0980 - root_mean_squared_error: 0.3131 - val_loss: 2.5853 - val_root_mean_squared_error: 1.6079
# Epoch 30/100
# 12/12 - 0s - loss: 0.0958 - root_mean_squared_error: 0.3095 - val_loss: 2.7484 - val_root_mean_squared_error: 1.6578
# Epoch 31/100
# 12/12 - 0s - loss: 0.0939 - root_mean_squared_error: 0.3064 - val_loss: 2.7443 - val_root_mean_squared_error: 1.6566
# Epoch 32/100
# 12/12 - 0s - loss: 0.1025 - root_mean_squared_error: 0.3202 - val_loss: 2.8834 - val_root_mean_squared_error: 1.6981
# Epoch 33/100
# 12/12 - 0s - loss: 0.0914 - root_mean_squared_error: 0.3023 - val_loss: 2.6485 - val_root_mean_squared_error: 1.6274
# Epoch 34/100
# 12/12 - 0s - loss: 0.0903 - root_mean_squared_error: 0.3005 - val_loss: 2.7035 - val_root_mean_squared_error: 1.6442
# Epoch 35/100
# 12/12 - 0s - loss: 0.0926 - root_mean_squared_error: 0.3043 - val_loss: 2.8770 - val_root_mean_squared_error: 1.6962
# Epoch 36/100
# 12/12 - 0s - loss: 0.0902 - root_mean_squared_error: 0.3003 - val_loss: 2.5349 - val_root_mean_squared_error: 1.5921
# Epoch 37/100
# 12/12 - 0s - loss: 0.0962 - root_mean_squared_error: 0.3102 - val_loss: 2.9711 - val_root_mean_squared_error: 1.7237
# Epoch 38/100
# 12/12 - 0s - loss: 0.0935 - root_mean_squared_error: 0.3058 - val_loss: 2.5481 - val_root_mean_squared_error: 1.5963
# Epoch 39/100
# 12/12 - 0s - loss: 0.0879 - root_mean_squared_error: 0.2965 - val_loss: 2.6263 - val_root_mean_squared_error: 1.6206
# Epoch 40/100
# 12/12 - 0s - loss: 0.0933 - root_mean_squared_error: 0.3054 - val_loss: 2.7243 - val_root_mean_squared_error: 1.6506
# Epoch 41/100
# 12/12 - 0s - loss: 0.0824 - root_mean_squared_error: 0.2871 - val_loss: 2.5529 - val_root_mean_squared_error: 1.5978
# Epoch 42/100
# 12/12 - 0s - loss: 0.0941 - root_mean_squared_error: 0.3068 - val_loss: 2.7580 - val_root_mean_squared_error: 1.6607
# Epoch 43/100
# 12/12 - 0s - loss: 0.0799 - root_mean_squared_error: 0.2827 - val_loss: 2.7428 - val_root_mean_squared_error: 1.6561
# Epoch 44/100
# 12/12 - 0s - loss: 0.0800 - root_mean_squared_error: 0.2828 - val_loss: 2.7163 - val_root_mean_squared_error: 1.6481
# Epoch 45/100
# 12/12 - 0s - loss: 0.0808 - root_mean_squared_error: 0.2842 - val_loss: 2.8860 - val_root_mean_squared_error: 1.6988
# Epoch 46/100
# 12/12 - 0s - loss: 0.0761 - root_mean_squared_error: 0.2758 - val_loss: 2.7183 - val_root_mean_squared_error: 1.6487
# Epoch 47/100
# 12/12 - 0s - loss: 0.0747 - root_mean_squared_error: 0.2733 - val_loss: 3.1459 - val_root_mean_squared_error: 1.7737
# Epoch 48/100
# 12/12 - 0s - loss: 0.0777 - root_mean_squared_error: 0.2788 - val_loss: 2.9967 - val_root_mean_squared_error: 1.7311
# Epoch 49/100
# 12/12 - 0s - loss: 0.0840 - root_mean_squared_error: 0.2897 - val_loss: 2.5537 - val_root_mean_squared_error: 1.5980
# Epoch 50/100
# 12/12 - 0s - loss: 0.0733 - root_mean_squared_error: 0.2707 - val_loss: 2.8967 - val_root_mean_squared_error: 1.7020
# Epoch 51/100
# 12/12 - 0s - loss: 0.0806 - root_mean_squared_error: 0.2839 - val_loss: 2.5255 - val_root_mean_squared_error: 1.5892
# Epoch 52/100
# 12/12 - 0s - loss: 0.0786 - root_mean_squared_error: 0.2804 - val_loss: 2.6887 - val_root_mean_squared_error: 1.6397
# Epoch 53/100
# 12/12 - 0s - loss: 0.0771 - root_mean_squared_error: 0.2777 - val_loss: 2.6897 - val_root_mean_squared_error: 1.6400
# Epoch 54/100
# 12/12 - 0s - loss: 0.0720 - root_mean_squared_error: 0.2683 - val_loss: 2.8155 - val_root_mean_squared_error: 1.6779
# Epoch 55/100
# 12/12 - 0s - loss: 0.0713 - root_mean_squared_error: 0.2670 - val_loss: 2.8078 - val_root_mean_squared_error: 1.6757
# Epoch 56/100
# 12/12 - 0s - loss: 0.0874 - root_mean_squared_error: 0.2956 - val_loss: 2.3580 - val_root_mean_squared_error: 1.5356
# Epoch 57/100
# 12/12 - 0s - loss: 0.0817 - root_mean_squared_error: 0.2859 - val_loss: 2.8863 - val_root_mean_squared_error: 1.6989
# Epoch 58/100
# 12/12 - 0s - loss: 0.0757 - root_mean_squared_error: 0.2752 - val_loss: 2.6576 - val_root_mean_squared_error: 1.6302
# Epoch 59/100
# 12/12 - 0s - loss: 0.0741 - root_mean_squared_error: 0.2722 - val_loss: 2.3562 - val_root_mean_squared_error: 1.5350
# Epoch 60/100
# 12/12 - 0s - loss: 0.0754 - root_mean_squared_error: 0.2745 - val_loss: 2.8200 - val_root_mean_squared_error: 1.6793
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# ------- store 6 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.1675 - root_mean_squared_error: 1.0805 - val_loss: 1.0174 - val_root_mean_squared_error: 1.0087
# Epoch 2/100
# 12/12 - 0s - loss: 0.5048 - root_mean_squared_error: 0.7105 - val_loss: 0.9474 - val_root_mean_squared_error: 0.9734
# Epoch 3/100
# 12/12 - 0s - loss: 0.3607 - root_mean_squared_error: 0.6006 - val_loss: 1.0661 - val_root_mean_squared_error: 1.0325
# Epoch 4/100
# 12/12 - 0s - loss: 0.2602 - root_mean_squared_error: 0.5101 - val_loss: 1.2415 - val_root_mean_squared_error: 1.1142
# Epoch 5/100
# 12/12 - 0s - loss: 0.2324 - root_mean_squared_error: 0.4821 - val_loss: 1.2113 - val_root_mean_squared_error: 1.1006
# Epoch 6/100
# 12/12 - 0s - loss: 0.2116 - root_mean_squared_error: 0.4600 - val_loss: 1.1434 - val_root_mean_squared_error: 1.0693
# Epoch 7/100
# 12/12 - 0s - loss: 0.1896 - root_mean_squared_error: 0.4354 - val_loss: 1.1474 - val_root_mean_squared_error: 1.0712
# Epoch 8/100
# 12/12 - 0s - loss: 0.1937 - root_mean_squared_error: 0.4402 - val_loss: 1.2422 - val_root_mean_squared_error: 1.1145
# Epoch 9/100
# 12/12 - 0s - loss: 0.1652 - root_mean_squared_error: 0.4064 - val_loss: 1.4376 - val_root_mean_squared_error: 1.1990
# Epoch 10/100
# 12/12 - 0s - loss: 0.1614 - root_mean_squared_error: 0.4018 - val_loss: 2.0396 - val_root_mean_squared_error: 1.4281
# Epoch 11/100
# 12/12 - 0s - loss: 0.1544 - root_mean_squared_error: 0.3930 - val_loss: 2.2366 - val_root_mean_squared_error: 1.4955
# Epoch 12/100
# 12/12 - 0s - loss: 0.1571 - root_mean_squared_error: 0.3963 - val_loss: 2.4183 - val_root_mean_squared_error: 1.5551
# Epoch 13/100
# 12/12 - 0s - loss: 0.1287 - root_mean_squared_error: 0.3588 - val_loss: 2.0134 - val_root_mean_squared_error: 1.4189
# Epoch 14/100
# 12/12 - 0s - loss: 0.1302 - root_mean_squared_error: 0.3609 - val_loss: 1.8984 - val_root_mean_squared_error: 1.3778
# Epoch 15/100
# 12/12 - 0s - loss: 0.1377 - root_mean_squared_error: 0.3711 - val_loss: 1.8801 - val_root_mean_squared_error: 1.3712
# Epoch 16/100
# 12/12 - 0s - loss: 0.1290 - root_mean_squared_error: 0.3592 - val_loss: 2.2131 - val_root_mean_squared_error: 1.4876
# Epoch 17/100
# 12/12 - 0s - loss: 0.1316 - root_mean_squared_error: 0.3628 - val_loss: 2.4404 - val_root_mean_squared_error: 1.5622
# Epoch 18/100
# 12/12 - 1s - loss: 0.1215 - root_mean_squared_error: 0.3486 - val_loss: 2.4891 - val_root_mean_squared_error: 1.5777
# Epoch 19/100
# 12/12 - 0s - loss: 0.1178 - root_mean_squared_error: 0.3431 - val_loss: 2.4888 - val_root_mean_squared_error: 1.5776
# Epoch 20/100
# 12/12 - 0s - loss: 0.1177 - root_mean_squared_error: 0.3431 - val_loss: 2.0928 - val_root_mean_squared_error: 1.4467
# Epoch 21/100
# 12/12 - 0s - loss: 0.1126 - root_mean_squared_error: 0.3356 - val_loss: 2.4601 - val_root_mean_squared_error: 1.5685
# Epoch 22/100
# 12/12 - 1s - loss: 0.1098 - root_mean_squared_error: 0.3314 - val_loss: 2.3088 - val_root_mean_squared_error: 1.5195
# Epoch 23/100
# 12/12 - 0s - loss: 0.1150 - root_mean_squared_error: 0.3391 - val_loss: 1.9924 - val_root_mean_squared_error: 1.4115
# Epoch 24/100
# 12/12 - 0s - loss: 0.1020 - root_mean_squared_error: 0.3193 - val_loss: 2.1121 - val_root_mean_squared_error: 1.4533
# Epoch 25/100
# 12/12 - 1s - loss: 0.1073 - root_mean_squared_error: 0.3276 - val_loss: 2.1713 - val_root_mean_squared_error: 1.4735
# Epoch 26/100
# 12/12 - 0s - loss: 0.1133 - root_mean_squared_error: 0.3367 - val_loss: 2.5415 - val_root_mean_squared_error: 1.5942
# Epoch 27/100
# 12/12 - 0s - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 2.2683 - val_root_mean_squared_error: 1.5061
# Epoch 28/100
# 12/12 - 0s - loss: 0.1010 - root_mean_squared_error: 0.3178 - val_loss: 2.2640 - val_root_mean_squared_error: 1.5046
# Epoch 29/100
# 12/12 - 0s - loss: 0.0978 - root_mean_squared_error: 0.3128 - val_loss: 2.5088 - val_root_mean_squared_error: 1.5839
# Epoch 30/100
# 12/12 - 0s - loss: 0.0986 - root_mean_squared_error: 0.3140 - val_loss: 2.1616 - val_root_mean_squared_error: 1.4702
# Epoch 31/100
# 12/12 - 0s - loss: 0.0994 - root_mean_squared_error: 0.3154 - val_loss: 2.2800 - val_root_mean_squared_error: 1.5100
# Epoch 32/100
# 12/12 - 0s - loss: 0.1116 - root_mean_squared_error: 0.3340 - val_loss: 2.1505 - val_root_mean_squared_error: 1.4665
# Epoch 33/100
# 12/12 - 0s - loss: 0.0950 - root_mean_squared_error: 0.3082 - val_loss: 2.5934 - val_root_mean_squared_error: 1.6104
# Epoch 34/100
# 12/12 - 0s - loss: 0.0918 - root_mean_squared_error: 0.3030 - val_loss: 2.0465 - val_root_mean_squared_error: 1.4306
# Epoch 35/100
# 12/12 - 0s - loss: 0.0993 - root_mean_squared_error: 0.3151 - val_loss: 2.4318 - val_root_mean_squared_error: 1.5594
# Epoch 36/100
# 12/12 - 0s - loss: 0.0969 - root_mean_squared_error: 0.3113 - val_loss: 2.3951 - val_root_mean_squared_error: 1.5476
# Epoch 37/100
# 12/12 - 1s - loss: 0.0991 - root_mean_squared_error: 0.3148 - val_loss: 2.8295 - val_root_mean_squared_error: 1.6821
# Epoch 38/100
# 12/12 - 0s - loss: 0.0947 - root_mean_squared_error: 0.3077 - val_loss: 2.5610 - val_root_mean_squared_error: 1.6003
# Epoch 39/100
# 12/12 - 0s - loss: 0.0917 - root_mean_squared_error: 0.3028 - val_loss: 2.7310 - val_root_mean_squared_error: 1.6526
# Epoch 40/100
# 12/12 - 1s - loss: 0.0973 - root_mean_squared_error: 0.3120 - val_loss: 2.3356 - val_root_mean_squared_error: 1.5283
# Epoch 41/100
# 12/12 - 1s - loss: 0.0894 - root_mean_squared_error: 0.2991 - val_loss: 2.4065 - val_root_mean_squared_error: 1.5513
# Epoch 42/100
# 12/12 - 1s - loss: 0.0999 - root_mean_squared_error: 0.3160 - val_loss: 2.1424 - val_root_mean_squared_error: 1.4637
# Epoch 43/100
# 12/12 - 1s - loss: 0.0849 - root_mean_squared_error: 0.2914 - val_loss: 2.2562 - val_root_mean_squared_error: 1.5021
# Epoch 44/100
# 12/12 - 1s - loss: 0.0852 - root_mean_squared_error: 0.2919 - val_loss: 2.3207 - val_root_mean_squared_error: 1.5234
# Epoch 45/100
# 12/12 - 0s - loss: 0.0842 - root_mean_squared_error: 0.2901 - val_loss: 2.3245 - val_root_mean_squared_error: 1.5246
# Epoch 46/100
# 12/12 - 0s - loss: 0.0843 - root_mean_squared_error: 0.2904 - val_loss: 2.5305 - val_root_mean_squared_error: 1.5908
# Epoch 47/100
# 12/12 - 0s - loss: 0.0806 - root_mean_squared_error: 0.2840 - val_loss: 2.7746 - val_root_mean_squared_error: 1.6657
# Epoch 48/100
# 12/12 - 1s - loss: 0.0835 - root_mean_squared_error: 0.2890 - val_loss: 2.4374 - val_root_mean_squared_error: 1.5612
# Epoch 49/100
# 12/12 - 1s - loss: 0.0934 - root_mean_squared_error: 0.3056 - val_loss: 2.2908 - val_root_mean_squared_error: 1.5135
# Epoch 50/100
# 12/12 - 0s - loss: 0.0761 - root_mean_squared_error: 0.2758 - val_loss: 2.8395 - val_root_mean_squared_error: 1.6851
# Epoch 51/100
# 12/12 - 0s - loss: 0.0812 - root_mean_squared_error: 0.2850 - val_loss: 2.5356 - val_root_mean_squared_error: 1.5924
# Epoch 52/100
# 12/12 - 0s - loss: 0.0832 - root_mean_squared_error: 0.2885 - val_loss: 2.5487 - val_root_mean_squared_error: 1.5965
# Epoch 53/100
# 12/12 - 0s - loss: 0.0799 - root_mean_squared_error: 0.2827 - val_loss: 1.9778 - val_root_mean_squared_error: 1.4064
# Epoch 54/100
# 12/12 - 0s - loss: 0.0751 - root_mean_squared_error: 0.2740 - val_loss: 2.6932 - val_root_mean_squared_error: 1.6411
# Epoch 55/100
# 12/12 - 1s - loss: 0.0733 - root_mean_squared_error: 0.2708 - val_loss: 2.6042 - val_root_mean_squared_error: 1.6137
# Epoch 56/100
# 12/12 - 0s - loss: 0.0918 - root_mean_squared_error: 0.3030 - val_loss: 2.2750 - val_root_mean_squared_error: 1.5083
# Epoch 57/100
# 12/12 - 1s - loss: 0.0838 - root_mean_squared_error: 0.2894 - val_loss: 2.4604 - val_root_mean_squared_error: 1.5686
# Epoch 58/100
# 12/12 - 1s - loss: 0.0808 - root_mean_squared_error: 0.2843 - val_loss: 2.3559 - val_root_mean_squared_error: 1.5349
# Epoch 59/100
# 12/12 - 1s - loss: 0.0768 - root_mean_squared_error: 0.2772 - val_loss: 2.1335 - val_root_mean_squared_error: 1.4606
# Epoch 60/100
# 12/12 - 1s - loss: 0.0818 - root_mean_squared_error: 0.2860 - val_loss: 2.2577 - val_root_mean_squared_error: 1.5026
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# ------- store 7 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.3826 - root_mean_squared_error: 1.1758 - val_loss: 928.3223 - val_root_mean_squared_error: 30.4684
# Epoch 2/100
# 12/12 - 0s - loss: 0.5712 - root_mean_squared_error: 0.7558 - val_loss: 935.6819 - val_root_mean_squared_error: 30.5889
# Epoch 3/100
# 12/12 - 0s - loss: 0.3745 - root_mean_squared_error: 0.6120 - val_loss: 936.6329 - val_root_mean_squared_error: 30.6045
# Epoch 4/100
# 12/12 - 0s - loss: 0.3329 - root_mean_squared_error: 0.5769 - val_loss: 938.0841 - val_root_mean_squared_error: 30.6282
# Epoch 5/100
# 12/12 - 1s - loss: 0.3159 - root_mean_squared_error: 0.5620 - val_loss: 938.4560 - val_root_mean_squared_error: 30.6342
# Epoch 6/100
# 12/12 - 0s - loss: 0.2819 - root_mean_squared_error: 0.5309 - val_loss: 937.9580 - val_root_mean_squared_error: 30.6261
# Epoch 7/100
# 12/12 - 0s - loss: 0.2544 - root_mean_squared_error: 0.5044 - val_loss: 937.1650 - val_root_mean_squared_error: 30.6132
# Epoch 8/100
# 12/12 - 1s - loss: 0.2309 - root_mean_squared_error: 0.4805 - val_loss: 936.8517 - val_root_mean_squared_error: 30.6080
# Epoch 9/100
# 12/12 - 0s - loss: 0.2325 - root_mean_squared_error: 0.4822 - val_loss: 937.2181 - val_root_mean_squared_error: 30.6140
# Epoch 10/100
# 12/12 - 0s - loss: 0.2018 - root_mean_squared_error: 0.4492 - val_loss: 938.3171 - val_root_mean_squared_error: 30.6320
# Epoch 11/100
# 12/12 - 0s - loss: 0.1933 - root_mean_squared_error: 0.4396 - val_loss: 939.4838 - val_root_mean_squared_error: 30.6510
# Epoch 12/100
# 12/12 - 1s - loss: 0.1816 - root_mean_squared_error: 0.4261 - val_loss: 940.6243 - val_root_mean_squared_error: 30.6696
# Epoch 13/100
# 12/12 - 1s - loss: 0.1714 - root_mean_squared_error: 0.4141 - val_loss: 939.9504 - val_root_mean_squared_error: 30.6586
# Epoch 14/100
# 12/12 - 1s - loss: 0.1684 - root_mean_squared_error: 0.4104 - val_loss: 941.8728 - val_root_mean_squared_error: 30.6899
# Epoch 15/100
# 12/12 - 0s - loss: 0.1577 - root_mean_squared_error: 0.3971 - val_loss: 945.3177 - val_root_mean_squared_error: 30.7460
# Epoch 16/100
# 12/12 - 1s - loss: 0.1505 - root_mean_squared_error: 0.3880 - val_loss: 947.3141 - val_root_mean_squared_error: 30.7785
# Epoch 17/100
# 12/12 - 0s - loss: 0.1443 - root_mean_squared_error: 0.3799 - val_loss: 953.9192 - val_root_mean_squared_error: 30.8856
# Epoch 18/100
# 12/12 - 1s - loss: 0.1376 - root_mean_squared_error: 0.3709 - val_loss: 949.1537 - val_root_mean_squared_error: 30.8083
# Epoch 19/100
# 12/12 - 0s - loss: 0.1451 - root_mean_squared_error: 0.3810 - val_loss: 949.0253 - val_root_mean_squared_error: 30.8063
# Epoch 20/100
# 12/12 - 1s - loss: 0.1296 - root_mean_squared_error: 0.3600 - val_loss: 953.8601 - val_root_mean_squared_error: 30.8846
# Epoch 21/100
# 12/12 - 0s - loss: 0.1339 - root_mean_squared_error: 0.3659 - val_loss: 958.1561 - val_root_mean_squared_error: 30.9541
# Epoch 22/100
# 12/12 - 1s - loss: 0.1324 - root_mean_squared_error: 0.3639 - val_loss: 956.4159 - val_root_mean_squared_error: 30.9260
# Epoch 23/100
# 12/12 - 1s - loss: 0.1286 - root_mean_squared_error: 0.3586 - val_loss: 958.3391 - val_root_mean_squared_error: 30.9571
# Epoch 24/100
# 12/12 - 1s - loss: 0.1270 - root_mean_squared_error: 0.3563 - val_loss: 958.7295 - val_root_mean_squared_error: 30.9634
# Epoch 25/100
# 12/12 - 1s - loss: 0.1209 - root_mean_squared_error: 0.3477 - val_loss: 950.4719 - val_root_mean_squared_error: 30.8297
# Epoch 26/100
# 12/12 - 0s - loss: 0.1314 - root_mean_squared_error: 0.3625 - val_loss: 960.8343 - val_root_mean_squared_error: 30.9973
# Epoch 27/100
# 12/12 - 1s - loss: 0.1254 - root_mean_squared_error: 0.3541 - val_loss: 968.1011 - val_root_mean_squared_error: 31.1143
# Epoch 28/100
# 12/12 - 0s - loss: 0.1235 - root_mean_squared_error: 0.3514 - val_loss: 966.5051 - val_root_mean_squared_error: 31.0887
# Epoch 29/100
# 12/12 - 0s - loss: 0.1269 - root_mean_squared_error: 0.3562 - val_loss: 963.4838 - val_root_mean_squared_error: 31.0400
# Epoch 30/100
# 12/12 - 1s - loss: 0.1265 - root_mean_squared_error: 0.3556 - val_loss: 972.4856 - val_root_mean_squared_error: 31.1847
# Restoring model weights from the end of the best epoch.
# Epoch 00030: early stopping
# ------- store 8 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.1217 - root_mean_squared_error: 1.0591 - val_loss: 232.8485 - val_root_mean_squared_error: 15.2594
# Epoch 2/100
# 12/12 - 0s - loss: 0.4779 - root_mean_squared_error: 0.6913 - val_loss: 233.4697 - val_root_mean_squared_error: 15.2797
# Epoch 3/100
# 12/12 - 0s - loss: 0.3353 - root_mean_squared_error: 0.5790 - val_loss: 235.9961 - val_root_mean_squared_error: 15.3622
# Epoch 4/100
# 12/12 - 0s - loss: 0.2517 - root_mean_squared_error: 0.5017 - val_loss: 238.7038 - val_root_mean_squared_error: 15.4500
# Epoch 5/100
# 12/12 - 0s - loss: 0.2334 - root_mean_squared_error: 0.4831 - val_loss: 238.7985 - val_root_mean_squared_error: 15.4531
# Epoch 6/100
# 12/12 - 0s - loss: 0.2070 - root_mean_squared_error: 0.4550 - val_loss: 237.5507 - val_root_mean_squared_error: 15.4127
# Epoch 7/100
# 12/12 - 0s - loss: 0.1909 - root_mean_squared_error: 0.4369 - val_loss: 237.0076 - val_root_mean_squared_error: 15.3951
# Epoch 8/100
# 12/12 - 0s - loss: 0.1847 - root_mean_squared_error: 0.4298 - val_loss: 237.7554 - val_root_mean_squared_error: 15.4193
# Epoch 9/100
# 12/12 - 0s - loss: 0.1651 - root_mean_squared_error: 0.4063 - val_loss: 237.9244 - val_root_mean_squared_error: 15.4248
# Epoch 10/100
# 12/12 - 0s - loss: 0.1506 - root_mean_squared_error: 0.3881 - val_loss: 237.7584 - val_root_mean_squared_error: 15.4194
# Epoch 11/100
# 12/12 - 0s - loss: 0.1531 - root_mean_squared_error: 0.3912 - val_loss: 237.5893 - val_root_mean_squared_error: 15.4139
# Epoch 12/100
# 12/12 - 0s - loss: 0.1415 - root_mean_squared_error: 0.3762 - val_loss: 239.0927 - val_root_mean_squared_error: 15.4626
# Epoch 13/100
# 12/12 - 0s - loss: 0.1291 - root_mean_squared_error: 0.3593 - val_loss: 239.1859 - val_root_mean_squared_error: 15.4656
# Epoch 14/100
# 12/12 - 0s - loss: 0.1299 - root_mean_squared_error: 0.3604 - val_loss: 239.1998 - val_root_mean_squared_error: 15.4661
# Epoch 15/100
# 12/12 - 0s - loss: 0.1269 - root_mean_squared_error: 0.3562 - val_loss: 239.7635 - val_root_mean_squared_error: 15.4843
# Epoch 16/100
# 12/12 - 0s - loss: 0.1233 - root_mean_squared_error: 0.3512 - val_loss: 240.4064 - val_root_mean_squared_error: 15.5050
# Epoch 17/100
# 12/12 - 0s - loss: 0.1279 - root_mean_squared_error: 0.3577 - val_loss: 243.0011 - val_root_mean_squared_error: 15.5885
# Epoch 18/100
# 12/12 - 0s - loss: 0.1131 - root_mean_squared_error: 0.3363 - val_loss: 242.5003 - val_root_mean_squared_error: 15.5724
# Epoch 19/100
# 12/12 - 0s - loss: 0.1113 - root_mean_squared_error: 0.3337 - val_loss: 241.8320 - val_root_mean_squared_error: 15.5509
# Epoch 20/100
# 12/12 - 0s - loss: 0.1118 - root_mean_squared_error: 0.3344 - val_loss: 241.6749 - val_root_mean_squared_error: 15.5459
# Epoch 21/100
# 12/12 - 0s - loss: 0.1108 - root_mean_squared_error: 0.3329 - val_loss: 245.1915 - val_root_mean_squared_error: 15.6586
# Epoch 22/100
# 12/12 - 0s - loss: 0.1042 - root_mean_squared_error: 0.3228 - val_loss: 242.0190 - val_root_mean_squared_error: 15.5570
# Epoch 23/100
# 12/12 - 0s - loss: 0.1049 - root_mean_squared_error: 0.3239 - val_loss: 243.7550 - val_root_mean_squared_error: 15.6127
# Epoch 24/100
# 12/12 - 0s - loss: 0.1035 - root_mean_squared_error: 0.3217 - val_loss: 242.7558 - val_root_mean_squared_error: 15.5806
# Epoch 25/100
# 12/12 - 0s - loss: 0.0995 - root_mean_squared_error: 0.3154 - val_loss: 242.9686 - val_root_mean_squared_error: 15.5874
# Epoch 26/100
# 12/12 - 0s - loss: 0.1013 - root_mean_squared_error: 0.3183 - val_loss: 247.4149 - val_root_mean_squared_error: 15.7294
# Epoch 27/100
# 12/12 - 0s - loss: 0.0930 - root_mean_squared_error: 0.3049 - val_loss: 248.0175 - val_root_mean_squared_error: 15.7486
# Epoch 28/100
# 12/12 - 0s - loss: 0.0971 - root_mean_squared_error: 0.3115 - val_loss: 248.7485 - val_root_mean_squared_error: 15.7718
# Epoch 29/100
# 12/12 - 0s - loss: 0.0923 - root_mean_squared_error: 0.3039 - val_loss: 248.2162 - val_root_mean_squared_error: 15.7549
# Epoch 30/100
# 12/12 - 0s - loss: 0.0957 - root_mean_squared_error: 0.3093 - val_loss: 247.8321 - val_root_mean_squared_error: 15.7427
# Epoch 31/100
# 12/12 - 0s - loss: 0.0902 - root_mean_squared_error: 0.3003 - val_loss: 247.5790 - val_root_mean_squared_error: 15.7346
# Epoch 32/100
# 12/12 - 0s - loss: 0.0901 - root_mean_squared_error: 0.3001 - val_loss: 248.8993 - val_root_mean_squared_error: 15.7765
# Epoch 33/100
# 12/12 - 0s - loss: 0.0833 - root_mean_squared_error: 0.2886 - val_loss: 248.6136 - val_root_mean_squared_error: 15.7675
# Epoch 34/100
# 12/12 - 0s - loss: 0.0842 - root_mean_squared_error: 0.2902 - val_loss: 248.2506 - val_root_mean_squared_error: 15.7560
# Epoch 35/100
# 12/12 - 1s - loss: 0.0894 - root_mean_squared_error: 0.2989 - val_loss: 249.0045 - val_root_mean_squared_error: 15.7799
# Epoch 36/100
# 12/12 - 1s - loss: 0.0872 - root_mean_squared_error: 0.2953 - val_loss: 248.2910 - val_root_mean_squared_error: 15.7573
# Epoch 37/100
# 12/12 - 1s - loss: 0.0928 - root_mean_squared_error: 0.3046 - val_loss: 249.9901 - val_root_mean_squared_error: 15.8111
# Epoch 38/100
# 12/12 - 1s - loss: 0.0920 - root_mean_squared_error: 0.3033 - val_loss: 248.0323 - val_root_mean_squared_error: 15.7490
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# ------- store 9 -------
# Epoch 1/100
# 12/12 - 4s - loss: 1.3089 - root_mean_squared_error: 1.1441 - val_loss: 14.7542 - val_root_mean_squared_error: 3.8411
# Epoch 2/100
# 12/12 - 0s - loss: 0.5501 - root_mean_squared_error: 0.7417 - val_loss: 15.3094 - val_root_mean_squared_error: 3.9127
# Epoch 3/100
# 12/12 - 1s - loss: 0.3692 - root_mean_squared_error: 0.6076 - val_loss: 15.5454 - val_root_mean_squared_error: 3.9428
# Epoch 4/100
# 12/12 - 0s - loss: 0.3197 - root_mean_squared_error: 0.5654 - val_loss: 15.8096 - val_root_mean_squared_error: 3.9761
# Epoch 5/100
# 12/12 - 0s - loss: 0.2936 - root_mean_squared_error: 0.5419 - val_loss: 15.8959 - val_root_mean_squared_error: 3.9870
# Epoch 6/100
# 12/12 - 1s - loss: 0.2616 - root_mean_squared_error: 0.5115 - val_loss: 15.9872 - val_root_mean_squared_error: 3.9984
# Epoch 7/100
# 12/12 - 1s - loss: 0.2404 - root_mean_squared_error: 0.4903 - val_loss: 16.0590 - val_root_mean_squared_error: 4.0074
# Epoch 8/100
# 12/12 - 1s - loss: 0.2243 - root_mean_squared_error: 0.4736 - val_loss: 16.0260 - val_root_mean_squared_error: 4.0033
# Epoch 9/100
# 12/12 - 1s - loss: 0.2059 - root_mean_squared_error: 0.4537 - val_loss: 16.3240 - val_root_mean_squared_error: 4.0403
# Epoch 10/100
# 12/12 - 1s - loss: 0.1944 - root_mean_squared_error: 0.4409 - val_loss: 16.5494 - val_root_mean_squared_error: 4.0681
# Epoch 11/100
# 12/12 - 1s - loss: 0.1961 - root_mean_squared_error: 0.4428 - val_loss: 17.3437 - val_root_mean_squared_error: 4.1646
# Epoch 12/100
# 12/12 - 1s - loss: 0.1757 - root_mean_squared_error: 0.4191 - val_loss: 16.9506 - val_root_mean_squared_error: 4.1171
# Epoch 13/100
# 12/12 - 0s - loss: 0.1773 - root_mean_squared_error: 0.4211 - val_loss: 17.1211 - val_root_mean_squared_error: 4.1378
# Epoch 14/100
# 12/12 - 0s - loss: 0.1674 - root_mean_squared_error: 0.4092 - val_loss: 17.9269 - val_root_mean_squared_error: 4.2340
# Epoch 15/100
# 12/12 - 0s - loss: 0.1581 - root_mean_squared_error: 0.3977 - val_loss: 18.2213 - val_root_mean_squared_error: 4.2686
# Epoch 16/100
# 12/12 - 0s - loss: 0.1514 - root_mean_squared_error: 0.3891 - val_loss: 18.4018 - val_root_mean_squared_error: 4.2897
# Epoch 17/100
# 12/12 - 0s - loss: 0.1539 - root_mean_squared_error: 0.3923 - val_loss: 19.1323 - val_root_mean_squared_error: 4.3740
# Epoch 18/100
# 12/12 - 0s - loss: 0.1479 - root_mean_squared_error: 0.3845 - val_loss: 19.1306 - val_root_mean_squared_error: 4.3739
# Epoch 19/100
# 12/12 - 1s - loss: 0.1501 - root_mean_squared_error: 0.3875 - val_loss: 19.4801 - val_root_mean_squared_error: 4.4136
# Epoch 20/100
# 12/12 - 0s - loss: 0.1364 - root_mean_squared_error: 0.3693 - val_loss: 19.0708 - val_root_mean_squared_error: 4.3670
# Epoch 21/100
# 12/12 - 1s - loss: 0.1323 - root_mean_squared_error: 0.3637 - val_loss: 19.2321 - val_root_mean_squared_error: 4.3854
# Epoch 22/100
# 12/12 - 1s - loss: 0.1341 - root_mean_squared_error: 0.3662 - val_loss: 18.2254 - val_root_mean_squared_error: 4.2691
# Epoch 23/100
# 12/12 - 1s - loss: 0.1284 - root_mean_squared_error: 0.3584 - val_loss: 19.0131 - val_root_mean_squared_error: 4.3604
# Epoch 24/100
# 12/12 - 1s - loss: 0.1342 - root_mean_squared_error: 0.3663 - val_loss: 19.2182 - val_root_mean_squared_error: 4.3839
# Epoch 25/100
# 12/12 - 1s - loss: 0.1271 - root_mean_squared_error: 0.3564 - val_loss: 19.8810 - val_root_mean_squared_error: 4.4588
# Epoch 26/100
# 12/12 - 1s - loss: 0.1354 - root_mean_squared_error: 0.3679 - val_loss: 20.8644 - val_root_mean_squared_error: 4.5678
# Epoch 27/100
# 12/12 - 1s - loss: 0.1228 - root_mean_squared_error: 0.3504 - val_loss: 20.0554 - val_root_mean_squared_error: 4.4783
# Epoch 28/100
# 12/12 - 0s - loss: 0.1242 - root_mean_squared_error: 0.3525 - val_loss: 19.9884 - val_root_mean_squared_error: 4.4708
# Epoch 29/100
# 12/12 - 0s - loss: 0.1198 - root_mean_squared_error: 0.3461 - val_loss: 20.1651 - val_root_mean_squared_error: 4.4906
# Epoch 30/100
# 12/12 - 1s - loss: 0.1231 - root_mean_squared_error: 0.3508 - val_loss: 20.3835 - val_root_mean_squared_error: 4.5148
# Epoch 31/100
# 12/12 - 0s - loss: 0.1146 - root_mean_squared_error: 0.3386 - val_loss: 21.4011 - val_root_mean_squared_error: 4.6261
# Epoch 32/100
# 12/12 - 0s - loss: 0.1110 - root_mean_squared_error: 0.3331 - val_loss: 21.5809 - val_root_mean_squared_error: 4.6455
# Epoch 33/100
# 12/12 - 1s - loss: 0.1161 - root_mean_squared_error: 0.3407 - val_loss: 21.1919 - val_root_mean_squared_error: 4.6035
# Epoch 34/100
# 12/12 - 0s - loss: 0.1072 - root_mean_squared_error: 0.3274 - val_loss: 20.2332 - val_root_mean_squared_error: 4.4981
# Epoch 35/100
# 12/12 - 1s - loss: 0.1083 - root_mean_squared_error: 0.3291 - val_loss: 22.0841 - val_root_mean_squared_error: 4.6994
# Epoch 36/100
# 12/12 - 0s - loss: 0.1125 - root_mean_squared_error: 0.3354 - val_loss: 21.8288 - val_root_mean_squared_error: 4.6721
# Epoch 37/100
# 12/12 - 1s - loss: 0.0978 - root_mean_squared_error: 0.3127 - val_loss: 21.0169 - val_root_mean_squared_error: 4.5844
# Epoch 38/100
# 12/12 - 0s - loss: 0.1115 - root_mean_squared_error: 0.3340 - val_loss: 20.9517 - val_root_mean_squared_error: 4.5773
# Epoch 39/100
# 12/12 - 1s - loss: 0.1143 - root_mean_squared_error: 0.3382 - val_loss: 21.1593 - val_root_mean_squared_error: 4.5999
# Epoch 40/100
# 12/12 - 1s - loss: 0.1060 - root_mean_squared_error: 0.3256 - val_loss: 21.4155 - val_root_mean_squared_error: 4.6277
# Epoch 41/100
# 12/12 - 0s - loss: 0.1050 - root_mean_squared_error: 0.3240 - val_loss: 20.2285 - val_root_mean_squared_error: 4.4976
# Epoch 42/100
# 12/12 - 0s - loss: 0.1017 - root_mean_squared_error: 0.3190 - val_loss: 20.3687 - val_root_mean_squared_error: 4.5132
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping

# %%
### RMSE ON TEST DATA ###

error = {}

for store in range(10):
    
    error[store] = np.sqrt(mean_squared_error(reverse_test[:,store], pred_test_all[:,store]))

# %%
### PLOT RMSE ###

plt.figure(figsize=(14,5))
plt.bar(range(10), error.values())
plt.xticks(range(10), ['store_'+str(s) for s in range(10)])
plt.ylabel('error')
np.set_printoptions(False)

# %%
### UTILITY FUNCTION TO PLOT PREDICTION ###

def plot_predictions(y_true, y_pred, store, item):
    
    y_true = y_true.reshape(4,-1,10)
    y_pred = y_pred.reshape(4,-1,10)
    
    plt.plot(y_true[item,:,store], label='true')
    plt.plot(y_pred[item,:,store], label='prediction')
    plt.title(f"store: {store} item: {item}"); plt.legend()
    plt.ylabel('sales'); plt.xlabel('date')

# %%
plt.figure(figsize=(11,5))
plot_predictions(reverse_test, pred_test_all, 0,1)
